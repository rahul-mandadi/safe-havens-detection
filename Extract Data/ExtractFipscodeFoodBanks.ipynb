# %%
import pandas as pd
import numpy as np

# %%
law_df = pd.read_csv('../Data/Feeding_America_Food_Banks_View1.csv')
city_df = pd.read_csv('../Cleaned Data/cleaned_us_cities.csv')

# %%
law_df.head()
# Out:
#               X             Y  FEMA_Region  \
# 0 -8.100265e+06  5.083471e+06            1
# 1 -8.095874e+06  5.140930e+06            1
# 2 -8.083437e+06  5.220823e+06            1
# 3 -7.910998e+06  5.211109e+06            1
# 4 -7.983969e+06  5.202478e+06            1
#
#                            Food_Bank_Name  Member_Number  \
# 0                   Connecticut Food Bank             56
# 1                               Foodshare            144
# 2  The Food Bank of Western Massachusetts             35
# 3            The Greater Boston Food Bank              9
# 4        Worcester County Food Bank, Inc.            186
#
#                   Address         City State    Zip_Code  \
# 0      2 Research Parkway  Wallingford    CT       06492
# 1     450 Woodland Avenue   Bloomfield    CT  06002-1342
# 2  97 North Hatfield Road     Hatfield    MA       01038
# 3        70 South Bay Ave       Boston    MA  02118-2700
# 4     474 Boston Turnpike   Shrewsbury    MA       01545
#
#                      Web_Page                                Facebook_Page  \
# 0   http://www.ctfoodbank.org           http://www.facebook.com/CTFoodBank
# 1    http://www.foodshare.org            http://www.facebook.com/Foodshare
# 2  http://www.foodbankwma.org  http://www.facebook.com/FoodBankofWesternMA
# 3         http://www.gbfb.org       http://www.facebook.com/gr8bosfoodbank
# 4     http://www.foodbank.org    http://www.facebook.com/WorcesterFoodbank
#
#    FID       Status                              GlobalID
# 0    1     Unstable  d08f8f10-b551-48e1-a616-0a762c6d899c
# 1    2       Stable  25cd5db6-ec17-4b57-a8da-afeecc293d24
# 2    3  Stabilizing  335bcef8-154a-4cf2-bad3-f296042e0978
# 3    4  Stabilizing  c6bb0ce5-211f-448a-9fb9-94a14d329b16
# 4    5       Stable  90e7c1e9-3763-4f41-9cf9-dd3faf6ed4ba

# %%
law_df.columns
# Out:
# Index(['X', 'Y', 'FEMA_Region', 'Food_Bank_Name', 'Member_Number', 'Address',
#        'City', 'State', 'Zip_Code', 'Web_Page', 'Facebook_Page', 'FID',
#        'Status', 'GlobalID'],
#       dtype='object')

# %%
law_df_cleaned = law_df[['X', 'Y', 'FID', 'Food_Bank_Name', 'Address', 'City', 'Status']]

# %%
law_df_cleaned.head()
# Out:
#               X             Y  FID                          Food_Bank_Name  \
# 0 -8.100265e+06  5.083471e+06    1                   Connecticut Food Bank
# 1 -8.095874e+06  5.140930e+06    2                               Foodshare
# 2 -8.083437e+06  5.220823e+06    3  The Food Bank of Western Massachusetts
# 3 -7.910998e+06  5.211109e+06    4            The Greater Boston Food Bank
# 4 -7.983969e+06  5.202478e+06    5        Worcester County Food Bank, Inc.
#
#                   Address         City       Status
# 0      2 Research Parkway  Wallingford     Unstable
# 1     450 Woodland Avenue   Bloomfield       Stable
# 2  97 North Hatfield Road     Hatfield  Stabilizing
# 3        70 South Bay Ave       Boston  Stabilizing
# 4     474 Boston Turnpike   Shrewsbury       Stable

# %%
city_df.head()
# Out:
#    Unnamed: 0     city_id    city_name  fips_code
# 0           0  1840034016     New York      36081
# 1           1  1840020491  Los Angeles       6037
# 2           2  1840000494      Chicago      17031
# 3           3  1840015149        Miami      12086
# 4           4  1840020925      Houston      48201

# %%
# !pip install pyproj
# Out:
# Collecting pyproj
#   Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: certifi in c:\users\ashwi\appdata\local\programs\python\python312\lib\site-packages (from pyproj) (2024.7.4)
# Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#     --------------------------------------- 0.1/6.2 MB 1.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/6.2 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/6.2 MB 4.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.2 MB 5.4 MB/s eta 0:00:01
#    --------- ------------------------------ 1.5/6.2 MB 6.2 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.2 MB 7.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.2 MB 8.1 MB/s eta 0:00:01
#    -------------------- ------------------- 3.2/6.2 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 8.7 MB/s eta 0:00:01
#    --------------------------- ------------ 4.3/6.2 MB 9.1 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 9.7 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: pyproj
# Successfully installed pyproj-3.7.0
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyproj import Transformer

# Initialize the transformer
transformer = Transformer.from_crs("EPSG:3857", "EPSG:4326")

# Function to transform coordinates
def getLatLong(row):
    x = row['X']
    y = row['Y']
    lat, lon = transformer.transform(x, y)
    return pd.Series([lat, lon])

# Assuming df is your dataframe
# Apply the function and create two columns 'Lat' and 'Long'
law_df_cleaned[['Lat', 'Long']] = law_df_cleaned.apply(getLatLong, axis=1)

# Display the result
law_df_cleaned.head()
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_63024\2520621561.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   law_df_cleaned[['Lat', 'Long']] = law_df_cleaned.apply(getLatLong, axis=1)
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_63024\2520621561.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   law_df_cleaned[['Lat', 'Long']] = law_df_cleaned.apply(getLatLong, axis=1)
#               X             Y  FID                          Food_Bank_Name  \
# 0 -8.100265e+06  5.083471e+06    1                   Connecticut Food Bank
# 1 -8.095874e+06  5.140930e+06    2                               Foodshare
# 2 -8.083437e+06  5.220823e+06    3  The Food Bank of Western Massachusetts
# 3 -7.910998e+06  5.211109e+06    4            The Greater Boston Food Bank
# 4 -7.983969e+06  5.202478e+06    5        Worcester County Food Bank, Inc.
#
#                   Address         City       Status        Lat       Long
# 0      2 Research Parkway  Wallingford     Unstable  41.480469 -72.765918
# 1     450 Woodland Avenue   Bloomfield       Stable  41.866016 -72.726471
# 2  97 North Hatfield Road     Hatfield  Stabilizing  42.398251 -72.614750
# 3        70 South Bay Ave       Boston  Stabilizing  42.333775 -71.065704
# 4     474 Boston Turnpike   Shrewsbury       Stable  42.276431 -71.721210

# %%
law_df_cleaned = law_df_cleaned.rename(columns={'Lat': 'latitude', 'Long' : 'longitude'})

# %%
import requests
import pandas as pd
from tqdm import tqdm  # Import tqdm for progress tracking

# Define the function with logging for each request
def getCounty(row):
    lat = row['latitude']
    long = row['longitude']
    url = f"https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x={long}&y={lat}&benchmark=Public_AR_Census2020&vintage=Census2020_Census2020&format=json"
    
    try:
        response = requests.get(url)
        
        # Check for a valid response
        if response.status_code != 200:
            print(f"Failed to get data for latitude: {lat}, longitude: {long} (Status Code: {response.status_code})")
            return pd.Series([None, None])  # Handle failed requests

        data = response.json()
        
        # Extract county info if available
        if 'Counties' in data['result']['geographies'] and data['result']['geographies']['Counties']:
            county_info = data['result']['geographies']['Counties'][0]
            county_name = county_info['NAME']
            state = county_info['STATE']
            fips_code = county_info['COUNTY']
            fips = state + fips_code
            return pd.Series([county_name, fips])
        else:
            print(f"No county found for latitude: {lat}, longitude: {long}")
            return pd.Series([None, None])
    except Exception as e:
        print(f"Error occurred for latitude: {lat}, longitude: {long}: {e}")
        return pd.Series([None, None])  # Handle other errors

# Apply the function row-wise with tqdm progress bar
tqdm.pandas()  # Initialize tqdm for pandas
law_df_cleaned[['County', 'fips_code']] = law_df_cleaned.progress_apply(lambda row: getCounty(row), axis=1)
# Out:
# 100%|██████████| 201/201 [01:29<00:00,  2.25it/s]

# %%
law_df_cleaned.to_csv('../Data/law_fips.csv')
